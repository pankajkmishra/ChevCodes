# %% [markdown]
# # RTM Example with static scheduling
# We will perform RTM using the following steps:
# 1. Read the 10m resampled models output from the FWI notebook
#     * true model
#     * initial model
#     * fwi model
# 2. Visualize the models
# 3. Build a small local compute cluster (2 workers)
# 4. Create list of shot locations
# 5. Build F, the distributed block operator for seismic modeling
# 6. Use F and generate "observed data" in the true model
# 7. Apply simple direct arrival mute
# 8. Use the Jacobian of F to migrate the observed data in each model
# 9. Perform a little post migration filtering
# 10. Visualize Results
#
# #### Note on runtime
# This notebook takes approximately 1 hour to run for 24 shots with two workers on an Intel 8168.
#
# `lscpu` CPU information: `Intel(R) Xeon(R) Platinum 8168 CPU @ 2.70GHz`

# %% [markdown]
# ## Add required packages

# %%
using Distributed, PyPlot, Jets, JetPack, JetPackDSP, Printf

# %% [markdown]
# ## Record time for start of notebook

# %%
time_beg = time()
# Out:
# 1.606774185374033e9

# %% [markdown]
# ## 1. Read the models output from the FWI notebook

# %%
file1 = "../50_fwi/marmousi_resampled_10m_349x1701_vtrue.bin"
file2 = "../50_fwi/marmousi_resampled_10m_349x1701_vinit.bin"
filef = "../50_fwi/marmousi_resampled_10m_349x1701_vfwi.bin"

nz,nx = 751,1751
dz,dx = 10.0,10.0

v1_orig = read!(file1, Array{Float32}(undef,nz,nx))
v2_orig = read!(file2, Array{Float32}(undef,nz,nx));
vf_orig = read!(filef, Array{Float32}(undef,nz,nx));
# Out:
# MethodError: no method matching read!(::IOStream, ::Type{Array{Float32,N} where N})
# Closest candidates are:
#   read!(::IO, !Matched::BitArray) at bitarray.jl:1824
#   read!(!Matched::AbstractString, ::Any) at io.jl:420
#   read!(::IO, !Matched::Ref{T}) where T at io.jl:699
#   ...
#
# Stacktrace:
#  [1] (::Base.var"#298#299"{UnionAll})(::IOStream) at ./io.jl:420
#  [2] open(::Base.var"#298#299"{UnionAll}, ::String; kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at ./io.jl:325
#  [3] open(::Function, ::String) at ./io.jl:323
#  [4] read!(::String, ::Type{T} where T) at ./io.jl:420
#  [5] top-level scope at In[15]:8
#  [6] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %% [markdown]
# ####  Apply a 7x7 rectangular mix smoother
# We perform the RTM migration in slightly smoothed models.

# %%
ns = 21
P = JopPad(JetSpace(Float32,nz,nx), -ns:nz+ns, -ns:nx+ns, extend=true)
M = JopMix(range(P), (7,7))
R = JopPad(JetSpace(Float32,nz,nx), -ns:nz+ns, -ns:nx+ns, extend=false)

s1 = R' ∘ M ∘ P * (1 ./ v1_orig)
s2 = R' ∘ M ∘ P * (1 ./ v2_orig)
sf = R' ∘ M ∘ P * (1 ./ vf_orig)

v1 = 1 ./(s1);
v2 = 1 ./(s2);
vf = 1 ./(sf);

# %% [markdown]
# ## 2. Visualize the models

# %%
vmin,vmax = extrema(v1_orig)
@show vmin,vmax;

figure(figsize=(8,9)); clf()

subplot(3,2,1);imshow(v1_orig,aspect="auto",cmap="jet");
colorbar(orientation="horizontal");clim(vmin,vmax);
title("True Velocity")

subplot(3,2,2);imshow(v1,aspect="auto",cmap="jet");
colorbar(orientation="horizontal");clim(vmin,vmax);
title("True Velocity (smoothed)")


subplot(3,2,3);imshow(v2_orig,aspect="auto",cmap="jet");
colorbar(orientation="horizontal");clim(vmin,vmax);
title("Initial Velocity");

subplot(3,2,4);imshow(v2,aspect="auto",cmap="jet");
colorbar(orientation="horizontal");clim(vmin,vmax);
title("Initial Velocity (smoothed)");


subplot(3,2,5);imshow(vf_orig,aspect="auto",cmap="jet");
colorbar(orientation="horizontal");clim(vmin,vmax);
title("FWI Velocity");

subplot(3,2,6);imshow(vf,aspect="auto",cmap="jet");
colorbar(orientation="horizontal");clim(vmin,vmax);
title("FWI Velocity (smoothed)");

tight_layout()
# Out:
# Figure(PyObject <Figure size 800x900 with 12 Axes>)
# (vmin, vmax) = (1500.0f0, 4504.236f0)

# %% [markdown]
# ## 3. Build a small local compute cluster (2 workers)
#
# #### Setup OMP environment variables for the cluster
#
# In the distributed compute case the workers that we add would be on different hardware, and we might add tens of workers in 2D and hundreds in 3D. Here we run on a single machine with only 2 workers, and so we need to be careful with details related to high performance computing. If we did not specify thread affinity, the two workers would compete for the same physical cores and the modeling would be *incredibly* slow.
#
# We spin up the small 2-worker cluster by calling `addprocs(2)`, and because we set the environment variable `ENV["OMP_DISPLAY_ENV"] = "true"` we will see the OMP environment printed out on each worker. In that output (below) we can verify that half of the total threads (44/2 = 22) are assigned to each socket on this 2 socket system. You can obtain more details about the hardware with the shell command `lscpu`.
#
# We set four environment variables related to OpenMP:
# * `OMP_DISPLAY_ENV` prints out the OpenMP environment on each worker
# * `OMP_PROC_BIND` specifies that threads should be bound to physical cores
# * `OMP_NUM_THREADS` specifies the number of threads per workers is 1/2 the number of physical cores
# * `GOMP_CPU_AFFINITY` specifies which physical cores the threads run on for each worker
#
# If you run the shell command `top` during execution, you will see 3 julia processes: the main process and two workers. The two workers should generally have about 50% of the system, and `load average` should tend towards the physical number of cores.

# %%
nthread = Sys.CPU_THREADS
ENV["OMP_DISPLAY_ENV"] = "true"
ENV["OMP_PROC_BIND"] = "close"
ENV["OMP_NUM_THREADS"] = "$(div(nthread,2))" 
addprocs(2)
@show workers()
for k in 1:nworkers()
    place1 = (k - 1) * div(nthread,nworkers())
    place2 = (k + 0) * div(nthread,nworkers()) - 1
    @show place1, place2, nthread
    @spawnat workers()[k] ENV["GOMP_CPU_AFFINITY"] = "$(place1)-$(place2)";
end
# Out:
# workers() = [2, 3, 4, 5]
# (place1, place2, nthread) = (0, 1, 8)
# (place1, place2, nthread) = (2, 3, 8)
# (place1, place2, nthread) = (4, 5, 8)
# (place1, place2, nthread) = (6, 7, 8)

# %%
@everywhere using DistributedArrays, DistributedJets, Jets, JetPack, WaveFD, JetPackWaveFD, Random, LinearAlgebra
# Out:
#       From worker 4:
#       From worker 4:	OPENMP DISPLAY ENVIRONMENT BEGIN
#       From worker 4:	  _OPENMP = '201511'
#       From worker 4:	  OMP_DYNAMIC = 'FALSE'
#       From worker 4:	  OMP_NESTED = 'FALSE'
#       From worker 4:	  OMP_NUM_THREADS = '4'
#       From worker 4:	  OMP_SCHEDULE = 'DYNAMIC'
#       From worker 4:	  OMP_PROC_BIND = 'CLOSE'
#       From worker 4:	  OMP_PLACES = ''
#       From worker 4:	  OMP_STACKSIZE = '2097152'
#       From worker 4:	  OMP_WAIT_POLICY = 'PASSIVE'
#       From worker 4:	  OMP_THREAD_LIMIT = '4294967295'
#       From worker 4:	  OMP_MAX_ACTIVE_LEVELS = '2147483647'
#       From worker 4:	  OMP_CANCELLATION = 'FALSE'
#       From worker 4:	  OMP_DEFAULT_DEVICE = '0'
#       From worker 4:	  OMP_MAX_TASK_PRIORITY = '0'
#       From worker 4:	  OMP_DISPLAY_AFFINITY = 'FALSE'
#       From worker 4:	  OMP_AFFINITY_FORMAT = 'level %L thread %i affinity %A'
#       From worker 4:	OPENMP DISPLAY ENVIRONMENT END
#       From worker 5:
#       From worker 5:	OPENMP DISPLAY ENVIRONMENT BEGIN
#       From worker 5:	  _OPENMP = '201511'
#       From worker 5:	  OMP_DYNAMIC = 'FALSE'
#       From worker 5:	  OMP_NESTED = 'FALSE'
#       From worker 5:	  OMP_NUM_THREADS = '4'
#       From worker 5:	  OMP_SCHEDULE = 'DYNAMIC'
#       From worker 5:	  OMP_PROC_BIND = 'CLOSE'
#       From worker 5:	  OMP_PLACES = ''
#       From worker 5:	  OMP_STACKSIZE = '2097152'
#       From worker 5:	  OMP_WAIT_POLICY = 'PASSIVE'
#       From worker 5:	  OMP_THREAD_LIMIT = '4294967295'
#       From worker 5:	  OMP_MAX_ACTIVE_LEVELS = '2147483647'
#       From worker 5:	  OMP_CANCELLATION = 'FALSE'
#       From worker 5:	  OMP_DEFAULT_DEVICE = '0'
#       From worker 5:	  OMP_MAX_TASK_PRIORITY = '0'
#       From worker 5:	  OMP_DISPLAY_AFFINITY = 'FALSE'
#       From worker 5:	  OMP_AFFINITY_FORMAT = 'level %L thread %i affinity %A'
#       From worker 5:	OPENMP DISPLAY ENVIRONMENT END

# %% [markdown]
# ## 4. Create list of shot locations
# We use 100 shot locations, many times than our FWI example, and run at significantly higher frequency.

# %%
nshots = 100
sx = round.(Int,collect(range(0,stop=(nx-1)*dx,length=nshots)))
@show nshots;
@show sx;
# Out:
# nshots = 100
# sx = [0, 172, 343, 515, 687, 859, 1030, 1202, 1374, 1545, 1717, 1889, 2061, 2232, 2404, 2576, 2747, 2919, 3091, 3263, 3434, 3606, 3778, 3949, 4121, 4293, 4465, 4636, 4808, 4980, 5152, 5323, 5495, 5667, 5838, 6010, 6182, 6354, 6525, 6697, 6869, 7040, 7212, 7384, 7556, 7727, 7899, 8071, 8242, 8414, 8586, 8758, 8929, 9101, 9273, 9444, 9616, 9788, 9960, 10131, 10303, 10475, 10646, 10818, 10990, 11162, 11333, 11505, 11677, 11848, 12020, 12192, 12364, 12535, 12707, 12879, 13051, 13222, 13394, 13566, 13737, 13909, 14081, 14253, 14424, 14596, 14768, 14939, 15111, 15283, 15455, 15626, 15798, 15970, 16141, 16313, 16485, 16657, 16828, 17000]

# %% [markdown]
# ## 5. Build `F`, the distributed block operator for seismic modeling

# %% [markdown]
# #### Note on scratch space for temporary files
# When dealing with serialized nonlinear wavefields as in this example, we need to specify the location where scratch files will be written.
#
# You may need to change this to point to a temporary directory available on your system.

# %%
@everywhere scratch = "scratch"
@assert isdir(scratch)

# %%
# notice we model to significantly shorter time than for FWI
@everywhere begin
    ntrec = 3501
    dtrec = 0.002
    dtmod = 0.001
    fpeak = 10.0
end

@everywhere function makeF(i,nz,nx,dz,dx,sx)
    JopNlProp2DAcoIsoDenQ_DEO2_FDTD(;
        b = ones(Float32,nz,nx),
        nthreads = div(Sys.CPU_THREADS,2),
        ntrec = ntrec,
        dtrec = dtrec,
        dtmod = dtmod,
        dz = dz,
        dx = dx,
        wavelet = WaveletCausalRicker(f=fpeak),
        sx = sx[i],
        sz = dz,
        rx = dx*[0:1:nx-1;],
        rz = 2*dz*ones(length(0:1:nx-1)),
        nbz_cache = nz,
        nbx_cache = 16,
        comptype = UInt32,
        srcfieldfile = joinpath(scratch, "field-$i-$(randstring()).bin"),
        reportinterval=12001)
end

# %%
F = @blockop DArray(I->[makeF(i,nz,nx,dz,dx,sx) for i in I[1], j in I[2]], (nshots,1))
# Out:
# "Jet nonlinear operator, (349, 1701) → (595520100,)"

# %% [markdown]
# ## 6. Use `F` and generate "observed data" in the true model

# %%
t1 = @elapsed begin
    d1 = F*v1
end
@show t1;
# Out:
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-51-WBn8xDh7.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-1-e7NsdLjo.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-76-vUsJzyaZ.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-26-kWgzd6Yl.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   70.95 MCells/s (IO=25.87, EX=12.91, PR=56.98) -- rms d,p; 1.8517e-01 9.5247e-04
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-52-xY54h2x6.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   68.73 MCells/s (IO=24.73, EX=12.59, PR=58.40) -- rms d,p; 1.8233e-01 8.8982e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-77-Lh46VWzF.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   51.30 MCells/s (IO=21.30, EX=10.40, PR=64.40) -- rms d,p; 1.8232e-01 9.3634e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-27-xmmxRby5.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   50.05 MCells/s (IO=20.04, EX= 9.46, PR=66.65) -- rms d,p; 1.3618e-01 9.4708e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-2-thmjyKUu.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   74.17 MCells/s (IO=25.83, EX=10.11, PR=59.91) -- rms d,p; 1.8244e-01 8.9275e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-78-Z8XV390Z.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   71.00 MCells/s (IO=25.57, EX=11.06, PR=59.10) -- rms d,p; 1.8531e-01 9.3522e-04
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-53-CvGyjhgP.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   64.69 MCells/s (IO=21.00, EX= 8.11, PR=67.27) -- rms d,p; 1.8259e-01 9.3071e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-28-pJGhyHYD.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   63.04 MCells/s (IO=20.59, EX= 7.74, PR=67.94) -- rms d,p; 1.6038e-01 9.4374e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-3-55AWYMD3.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   87.03 MCells/s (IO=26.78, EX=11.09, PR=57.98) -- rms d,p; 1.8582e-01 9.4564e-04
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-54-QmNKiVcp.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   80.54 MCells/s (IO=24.91, EX=10.06, PR=61.04) -- rms d,p; 1.8300e-01 8.9866e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-79-8Fd0AhvV.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   63.72 MCells/s (IO=22.20, EX= 9.15, PR=64.93) -- rms d,p; 1.8277e-01 9.2223e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-29-M64xM9y2.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   82.81 MCells/s (IO=26.50, EX=13.11, PR=56.34) -- rms d,p; 1.8657e-01 9.5336e-04
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field
-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-97-XV8x9pd0.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   79.42 MCells/s (IO=24.21, EX= 9.69, PR=62.17) -- rms d,p; 1.8443e-01 1.0302e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-46-ZDzn2Mwb.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   85.70 MCells/s (IO=25.73, EX=10.51, PR=59.68) -- rms d,p; 1.8370e-01 9.1533e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-75-74J29Hu2.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   78.97 MCells/s (IO=23.62, EX= 9.25, PR=63.44) -- rms d,p; 1.6892e-01 9.5312e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-98-mLPFLoNJ.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   62.29 MCells/s (IO=19.97, EX= 7.58, PR=68.89) -- rms d,p; 1.7961e-01 9.3524e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-19-TCBSonqI.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   84.41 MCells/s (IO=26.35, EX=10.62, PR=58.96) -- rms d,p; 1.8308e-01 9.0256e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   80.95 MCells/s (IO=25.36, EX=10.74, PR=59.88) -- rms d,p; 1.8464e-01 9.9672e-04
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-47-AQR0PjDC.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   83.16 MCells/s (IO=22.24, EX= 8.80, PR=65.53) -- rms d,p; 1.6596e-01 9.4814e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-99-RJHER2Oq.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   79.05 MCells/s (IO=20.27, EX= 8.28, PR=68.01) -- rms d,p; 1.8021e-01 9.3818e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-20-IWSnpcAN.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001  104.66 MCells/s (IO=24.23, EX= 9.95, PR=62.15) -- rms d,p; 1.8489e-01 9.7574e-04
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-48-VEMMHc2a.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   91.09 MCells/s (IO=21.18, EX=10.22, PR=65.19) -- rms d,p; 1.6082e-01 9.3402e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-100-SdjYpVTP.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001  101.95 MCells/s (IO=23.77, EX=11.02, PR=61.64) -- rms d,p; 1.8493e-01 9.5269e-04
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-49-fw5f3KWk.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   79.72 MCells/s (IO=18.68, EX= 9.11, PR=69.00) -- rms d,p; 1.8062e-01 9.4180e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-21-5pUzxQc9.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   89.70 MCells/s (IO=20.69, EX= 8.43, PR=67.37) -- rms d,p; 1.3654e-01 9.2269e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001  108.16 MCells/s (IO=24.95, EX=10.77, PR=60.58) -- rms d,p; 1.8488e-01 9.4414e-04
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-50-Zhmbd3OZ.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   92.71 MCells/s (IO=18.14, EX= 7.67, PR=71.14) -- rms d,p; 1.8095e-01 9.4332e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-22-ohkRRH10.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001  145.26 MCells/s (IO=24.92, EX=10.37, PR=61.36) -- rms d,p; 1.8506e-01 9.5169e-04
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001  114.10 MCells/s (IO=17.55, EX= 7.96, PR=71.30) -- rms d,p; 1.8101e-01 9.4136e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-23-p0lkkABp.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001  120.52 MCells/s (IO=16.53, EX= 7.67, PR=72.64) -- rms d,p; 1.8114e-01 9.3936e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-24-p0YvYk9Z.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001  125.51 MCells/s (IO=17.01, EX= 8.62, PR=71.36) -- rms d,p; 1.8142e-01 9.3931e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-25-AzdoLmRZ.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001  128.14 MCells/s (IO=17.59, EX= 8.15, PR=71.05) -- rms d,p; 1.8186e-01 9.3901e-03
# t1 = 2193.501511068

# %%
@printf("Time for modeling %.2f minutes\n", t1 / 60)
# Out:
# Time for modeling 36.56 minutes

# %% [markdown]
# ## 7. Apply simple direct arrival mute
# We apply a simple mute based on the Marmousi water velocity of 1500 m/s and the offset from the traces headers.

# %% [markdown]
# #### Define two functions to implement the mute for distributed block arrays
# * The 1st function dispatches on the remote worker that "owns" the block of data
# * The 2nd function implements a simple step function mute.

# %%
@everywhere function timemute!(F, d::DBArray, watervel, tmute)
    @sync for pid in procs(d)
        @async remotecall_fetch(timemute_local!, pid, F, d, watervel, tmute)
    end
end

@everywhere function timemute_local!(F, d::DBArray{T}, watervel, tmute) where {T}
    for iblock in localblockindices(d)
        dᵢ = getblock(d, iblock)
        Fᵢ = getblock(F, iblock, 1)
        nt = state(Fᵢ, :ntrec)
        for i = 1:length(state(Fᵢ, :rx)) 
            rx = state(Fᵢ, :rx)
            rz = state(Fᵢ, :rz)
            sx = state(Fᵢ, :sx)
            sz = state(Fᵢ, :sz)
            dist = sqrt((sx[1] - rx[i])^2 + (sz[1] - rz[i])^2)
            time = dist / watervel
            tbeg = 1
            tend = min(nt,round(Int, (time + tmute) / state(Fᵢ,:dtrec)))
            dᵢ[tbeg:tend,i] .= 0
        end
    end
    nothing
end

# %% [markdown]
# #### Apply the mute and visualize the results for 2 shot gathers
# The mute time chosen is six periods (at Ricker peak frequency) beyond water arrival. Six periods was empirically tested to remove the refraction energy and improve the reflection image.

# %%
watervel = minimum(v1)
tmute = 7.5 / (2 * fpeak)
@show watervel
@show tmute

# copy distributed block array
d1_mute = zeros(range(F));
d1_mute .= d1;

# apply mute
timemute!(F, d1_mute, watervel, tmute)

# get local copies of 1st shot gather to plot
shots = [1, div(nshots,2), nshots]
local_d1 = [getblock(d1,k) for k in shots];
local_d1_mute = [getblock(d1_mute,k) for k in shots];
# Out:
# watervel = 1405.7601f0
# tmute = 0.375

# %%
scale = 20.0 / sqrt(norm(d1)^2 / length(d1))
@show scale

figure(figsize=(8,6)); clf()

subplot(2,2,1);
imshow(scale .* local_d1[1],cmap="gray",aspect="auto",clim=[-1,+1]);
title("Unmuted data for shot 1");

subplot(2,2,2);
imshow(scale .* local_d1_mute[1],cmap="gray",aspect="auto",clim=[-1,+1]);
title("Muted data for shot 1");

subplot(2,2,3);
imshow(scale .* local_d1[end],cmap="gray",aspect="auto",clim=[-1,+1]);
title("Unmuted data for shot $(nshots)");

subplot(2,2,4);
imshow(scale .* local_d1_mute[end],cmap="gray",aspect="auto",clim=[-1,+1]);
title("Muted data for shot $(nshots)");

tight_layout();
# Out:
# Figure(PyObject <Figure size 800x600 with 4 Axes>)
# scale = 111.03673349582927

# %% [markdown]
# ## 8. Use the Jacobian of `F` to migrate the observed data in each model
# Note there is no water bottom mute or preprocessing applied here at all, those would clearly be improvements to this brute force workflow.

# %% [markdown]
# #### Migrate in the true velocity model

# %%
t1 = @elapsed begin
    J1 = jacobian!(F, v1)
    illum1 = srcillum(J1)
    m1 = J1'*d1_mute;
end
@show extrema(m1)
@show extrema(illum1)
# Out:
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-26-kWgzd6Yl.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.1732e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-76-vUsJzyaZ.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.6454e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-1-e7NsdLjo.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 8.2214e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-51-WBn8xDh7.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 6.6445e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-77-Lh46VWzF.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.7104e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-52-xY54h2x6.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 6.9079e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-27-xmmxRby5.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.1894e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-2-thmjyKUu.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p;
bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.8726e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-47-AQR0PjDC.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0005e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-20-IWSnpcAN.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0152e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-73-iAMFKXPG.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.4001e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-98-mLPFLoNJ.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.9111e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-48-VEMMHc2a.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 9.9926e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-21-5pUzxQc9.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0770e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-74-xj3xp8vu.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.3405e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-99-RJHER2Oq.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.7359e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-49-fw5f3KWk.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 9.6315e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-22-ohkRRH10.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0462e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-75-74J29Hu2.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.4198e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-100-SdjYpVTP.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.7088e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-50-Zhmbd3OZ.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 8.0200e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-23-p0lkkABp.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0402e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-24-p0YvYk9Z.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0649e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-25-AzdoLmRZ.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.1220e-02 0.0000e+00
# extrema(m1) = (-0.11686186f0, 0.06430733f0)
# extrema(illum1) = (468.4125f0, 35257.223f0)
# (468.4125f0, 35257.223f0)

# %%
@printf("Migrate time true model; %12.4f minutes\n", t1 / 60)
# Out:
# Migrate time true model;      31.5611 minutes

# %% [markdown]
# #### Migrate in the initial velocity model

# %%
t2 = @elapsed begin
    J2 = jacobian!(F, v2)
    illum2 = srcillum(J2)
    m2 = J2'*d1_mute;
end
@show extrema(m2)
@show extrema(illum2)
# Out:
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-51-WBn8xDh7.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-76-vUsJzyaZ.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-26-kWgzd6Yl.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-1-e7NsdLjo.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   77.79 MCells/s (IO=29.15, EX=12.85, PR=54.48) -- rms d,p; 0.0000e+00 8.5884e-04
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   76.19 MCells/s (IO=28.44, EX=12.56, PR=55.54) -- rms d,p; 0.0000e+00 8.8675e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   64.96 MCells/s (IO=23.82, EX= 9.91, PR=63.09) -- rms d,p; 0.0000e+00 9.2400e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-52-xY54h2x6.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-77-Lh46VWzF.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-27-xmmxRby5.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   50.86 MCells/s (IO=19.90, EX= 7.38, PR=69.66) -- rms d,p; 0.0000e+00 9.4854e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-2-thmjyKUu.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   82.50 MCells/s (IO=30.71, EX=10.75, PR=54.97) -- rms d,p; 0.0000e+00 8.5493e-04
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   83.24 MCells/s (IO=23.58, EX=10.67, PR=62.04) -- rms d,p; 0.0000e+00 8.8687e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-53-CvGyjhgP.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-78-Z8XV390Z.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   61.23 MCells/s (IO=18.83, EX= 9.02, PR=68.83) -- rms d,p; 0.0000e+00 9.1667e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-28-pJGhyHYD.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   54.13 MCells/s (IO=20.87, EX= 7.58, PR=68.34) -- rms d,p; 0.0000e+00 9.5021e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   85.07 MCells/s (IO=25.33, EX=10.41, PR=60.39) -- rms d,p; 0.0000e+00 8.4261e-04
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   77.20 MCells/s (IO=27.41, EX=10.48, PR=58.57) -- rms d,p; 0.0000e+00 8.9224e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-3-55AWYMD3.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-54-QmNKiVcp.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-79-8Fd0AhvV.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   63.23 MCells/s (IO=22.45, EX= 7.49, PR=66.81) -- rms d,p; 0.0000e+00 9.0775e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   93.93 MCells/s (IO=25.96, EX= 9.84, PR=60.28) -- rms d,p; 0.0000e+00 8.2566e-04
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-29-M64xM9y2.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-55-r6CETTpy.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001
bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 8.5854e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-71-DeDMp51g.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.5063e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-96-slDqTs1T.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.8143e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-46-ZDzn2Mwb.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0257e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-19-TCBSonqI.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 9.7572e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-72-BEVSfXqG.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.5115e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-97-XV8x9pd0.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.8726e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-47-AQR0PjDC.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0005e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-20-IWSnpcAN.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0152e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-73-iAMFKXPG.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.4001e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-98-mLPFLoNJ.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.9111e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-48-VEMMHc2a.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 9.9926e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-21-5pUzxQc9.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0770e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-74-xj3xp8vu.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.3405e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-99-RJHER2Oq.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.7359e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-49-fw5f3KWk.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 9.6315e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-22-ohkRRH10.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0462e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-75-74J29Hu2.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.4198e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-100-SdjYpVTP.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.7088e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-50-Zhmbd3OZ.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 8.0200e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-23-p0lkkABp.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0402e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-24-p0YvYk9Z.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0649e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-25-AzdoLmRZ.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.1220e-02 0.0000e+00
# extrema(m2) = (-0.020824477f0, 0.015557269f0)
# extrema(illum2) = (648.1814f0, 35262.46f0)
# (648.1814f0, 35262.46f0)

# %%
@printf("Migrate time init model; %12.4f minutes\n", t2 / 60)
# Out:
# Migrate time init model;      74.4868 minutes

# %% [markdown]
# #### Migrate in the FWI velocity model

# %%
tf = @elapsed begin
    Jf = jacobian!(F, vf)
    illumf = srcillum(Jf)
    mf = Jf'*d1_mute;
end
@show extrema(mf)
@show extrema(illumf)
# Out:
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-1-e7NsdLjo.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-26-kWgzd6Yl.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-51-WBn8xDh7.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-76-vUsJzyaZ.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    1.49 MCells/s (IO= 1.06, EX= 0.64, PR= 1.75) -- rms d,p; 0.0000e+00 9.6524e-04
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    1.49 MCells/s (IO= 0.98, EX= 0.81, PR= 1.72) -- rms d,p; 0.0000e+00 8.8976e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    1.48 MCells/s (IO= 0.70, EX= 0.54, PR= 2.64) -- rms d,p; 0.0000e+00 9.3595e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-52-xY54h2x6.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-77-Lh46VWzF.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    1.48 MCells/s (IO= 0.75, EX= 0.47, PR= 2.86) -- rms d,p; 0.0000e+00 9.4882e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-27-xmmxRby5.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-2-thmjyKUu.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    0.90 MCells/s (IO= 0.36, EX= 0.12, PR= 0.59) -- rms d,p; 0.0000e+00 9.4644e-04
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    0.90 MCells/s (IO= 0.34, EX= 0.14, PR= 0.63) -- rms d,p; 0.0000e+00 8.9317e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-53-CvGyjhgP.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-78-Z8XV390Z.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    0.57 MCells/s (IO= 0.31, EX= 0.18, PR= 0.91) -- rms d,p; 0.0000e+00 9.3053e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-28-pJGhyHYD.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    0.42 MCells/s (IO= 0.35, EX= 0.16, PR= 1.19) -- rms d,p; 0.0000e+00 9.4479e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-3-55AWYMD3.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    0.46 MCells/s (IO= 0.48, EX= 0.33, PR= 1.04) -- rms d,p; 0.0000e+00 9.5389e-04
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    0.46 MCells/s (IO= 0.53, EX= 0.32, PR= 1.20) -- rms d,p; 0.0000e+00 8.9846e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-54-QmNKiVcp.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-79-8Fd0AhvV.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    0.67 MCells/s (IO= 0.60, EX= 0.45, PR= 2.01) -- rms d,p; 0.0000e+00 9.2190e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-29-M64xM9y2.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    1.72 MCells/s (IO= 1.39, EX= 1.34, PR= 3.53) -- rms d,p; 0.0000e+00 9.4619e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   64.18 MCells/s (IO=27.08, EX=22.62, PR=47.05) -- rms d,p; 0.0000e+00 9.4998e-04
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   65.80 MCells/s (IO=25.69, EX=20.01, PR=51.06) -- rms d,p; 0.0000e+00 8.9038e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-4-3ri7gWZs.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-55-r6CETTpy.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-80-UmSp4AIp.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   61.61 MCells/s (IO=23.30, EX=16.81, PR=56.77) -- rms d,p; 0.0000e+00 9.1215e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-30-19JWvBH7.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   87.03 MCells/s (IO=30.82, EX=10.16, PR=55.34) -- rms d,p; 0.0000e+00 1.0157e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   79.42 MCells/s (IO=27.89, EX=11.29, PR=57.36) -- rms d,p; 0.0000e+00 8.8531e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   64.61 MCells/s (IO=22.86, EX=10.79, PR=63.20) -- rms d,p; 0.0000e+00 9.4692e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-56-exskHbnS.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-81-BH30szJZ.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-5-C0YcbKVd.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   72.30 MCells/s (IO=24.83, EX=10.06, PR=61.81) -- rms d,p; 0.0000e+00 9.0425e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   88.16 MCells/s (IO=29.27, EX=11.75, PR=55.32) -- rms d,p; 0.0000e+00 1.0901e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-31-3kJt8xIf.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-57-NOR6DTm1.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   78.21 MCells/s (IO=28.31, EX= 8.72, PR=59.56) -- rms d,p; 0.0000e+00 8.9423e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-82-lz8nGwZd.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   65.15 MCells/s (IO=23.61, EX= 7.41, PR=65.74) -- rms d,p; 0.0000e+00 9.4135e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-6-o6bQ9TUO.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   85.57 MCells/s (IO=30.05, EX=11.14, PR=55.17) -- rms d,p; 0.0000e+00 1.0303e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   66.55 MCells/s (IO=24.70, EX= 8.98, PR=63.04) -- rms d,p; 0.0000e+00 8.9477e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-58-3jowGTAi.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   81.17 MCells/s (IO=28.82, EX=11.26, PR=56.41) -- rms d,p; 0.0000e+00 9.1206e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-32-IoiONVJb.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-83-qGjA98cp.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   61.73 MCells/s (IO=23.83, EX= 9.15, PR=63.82) -- rms d,p; 0.0000e+00 9.4178e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-7-V4D4GzMx.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   87.79 MCells/s (IO=30.06, EX=11.77, PR=54.64) -- rms d,p; 0.0000e+00 1.5938e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-59-DVTTe1qw.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   71.99 MCells/s (IO=26.00, EX=12.32, PR=58.40) -- rms d,p; 0.0000e+00 8.8503e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   76.47 MCells/s (IO=27.18, EX=14.39, PR=55.13) -- rms d,p; 0.0000e+00 9.2864e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-33-3kKCXqyr.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-84-2gCBWP5l.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   89.03 MCells/s (IO=30.78, EX=12.24, PR=53.39) -- rms d,p; 0.0000e+00 5.4206e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   64.00 MCells/s (IO=22.65, EX=11.23, PR=62.95) -- rms d,p; 0.0000e+00 9.4192e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-60-svk8RlNV.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-8-Ue4Evglr.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   73.48 MCells/s (IO=27.47, EX=10.15, PR=59.03) -- rms d,p; 0.0000e+00 8.7862e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001
bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   60.65 MCells/s (IO=22.16, EX=10.81, PR=63.83) -- rms d,p; 0.0000e+00 9.3851e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-96-slDqTs1T.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-18-vw0gWG5e.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   78.34 MCells/s (IO=29.07, EX=11.94, PR=55.55) -- rms d,p; 0.0000e+00 9.3409e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-73-iAMFKXPG.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   75.89 MCells/s (IO=29.04, EX=10.35, PR=57.24) -- rms d,p; 0.0000e+00 1.0407e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   69.81 MCells/s (IO=25.43, EX=10.73, PR=60.53) -- rms d,p; 0.0000e+00 9.5618e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-46-ZDzn2Mwb.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-97-XV8x9pd0.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    6.22 MCells/s (IO= 2.38, EX= 1.65, PR= 6.54) -- rms d,p; 0.0000e+00 9.3483e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    6.32 MCells/s (IO= 2.76, EX= 1.79, PR= 4.61) -- rms d,p; 0.0000e+00 9.2704e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-19-TCBSonqI.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-74-xj3xp8vu.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    6.14 MCells/s (IO= 2.95, EX= 2.88, PR= 5.79) -- rms d,p; 0.0000e+00 1.0153e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001    6.14 MCells/s (IO= 2.72, EX= 2.32, PR= 6.62) -- rms d,p; 0.0000e+00 9.5233e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-47-AQR0PjDC.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-98-mLPFLoNJ.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   69.93 MCells/s (IO=26.98, EX=19.39, PR=50.35) -- rms d,p; 0.0000e+00 9.1529e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-75-74J29Hu2.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   51.09 MCells/s (IO=20.94, EX=16.95, PR=59.07) -- rms d,p; 0.0000e+00 9.3779e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-20-IWSnpcAN.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   76.96 MCells/s (IO=29.29, EX=13.60, PR=53.85) -- rms d,p; 0.0000e+00 9.9918e-04
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-48-VEMMHc2a.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   64.54 MCells/s (IO=23.83, EX=11.00, PR=61.99) -- rms d,p; 0.0000e+00 9.4639e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   79.15 MCells/s (IO=27.92, EX=14.85, PR=53.81) -- rms d,p; 0.0000e+00 9.0233e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-99-RJHER2Oq.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   65.95 MCells/s (IO=22.40, EX=10.77, PR=63.67) -- rms d,p; 0.0000e+00 9.4157e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   88.64 MCells/s (IO=28.58, EX=11.77, PR=56.51) -- rms d,p; 0.0000e+00 9.7123e-04
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-21-5pUzxQc9.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-49-fw5f3KWk.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   86.63 MCells/s (IO=24.61, EX=10.36, PR=61.99) -- rms d,p; 0.0000e+00 9.3384e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-100-SdjYpVTP.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   95.68 MCells/s (IO=30.46, EX=10.33, PR=55.92) -- rms d,p; 0.0000e+00 9.6304e-04
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   76.70 MCells/s (IO=23.01, EX= 8.16, PR=65.79) -- rms d,p; 0.0000e+00 9.4313e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-50-Zhmbd3OZ.bin
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-22-ohkRRH10.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   86.62 MCells/s (IO=25.06, EX=11.06, PR=60.79) -- rms d,p; 0.0000e+00 9.2295e-03
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001  114.38 MCells/s (IO=29.94, EX= 8.61, PR=58.35) -- rms d,p; 0.0000e+00 9.6667e-04
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001   91.20 MCells/s (IO=22.47, EX= 6.98, PR=67.66) -- rms d,p; 0.0000e+00 9.4128e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-23-p0lkkABp.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7001  114.07 MCells/s (IO=20.36, EX= 9.00, PR=67.70) -- rms d,p; 0.0000e+00 9.3923e-03
# [ Info: nonlinear forward on IG-A23078.local, srcfieldfile=scratch/field-24-p0YvYk9Z.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, nonlinear forward, time step  7001 of  7
-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-93-xvvPnNXq.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.6087e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-16-Q2T1bqlr.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 8.9259e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-43-73pJCYVp.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 9.5150e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-69-ICJZaRRy.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.1434e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-94-nwfbgEM1.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.6472e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-44-M2CgJyii.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0022e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-17-KgNiPrRi.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 8.3267e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-70-kV6lMogX.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.3947e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-95-JpvaC9QK.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.7602e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-45-xhheyFG5.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0668e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-18-vw0gWG5e.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 8.5854e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-71-DeDMp51g.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.5063e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-96-slDqTs1T.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.8143e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-46-ZDzn2Mwb.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0257e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-19-TCBSonqI.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 9.7572e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-72-BEVSfXqG.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.5115e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-97-XV8x9pd0.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.8726e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-47-AQR0PjDC.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0005e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-20-IWSnpcAN.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 1.0152e-02 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-73-iAMFKXPG.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 7.4001e-03 0.0000e+00
# [ Info: linear adjoint on IG-A23078.local, srcfieldfile=scratch/field-98-mLPFLoNJ.bin
# [ Info: Prop2DAcoIsoDenQ_DEO2_FDTD, adjoint, time step     1 of  7001    0.00 MCells/s (IO= 0.00, EX= 0.00, IM= 0.00, PR= 0.00) -- rms d,p; 5.9111e-03 0.0000e+00

# %%
@printf("Migrate time FWI  model; %12.4f minutes\n", tf / 60)

# %% [markdown]
# ## 9. Perform a little post migration filtering

# %% [markdown]
# #### Laplacian filter to remove low frequency backscattered noise

# %%
L = JopLaplacian(JetSpace(Float32,nz,nx))

# %% [markdown]
# #### Apply low cut filter, illumination compensation, and gain

# %%
g = ([0:(nz-1);]*dz).^2 * ones(1,nx);

img1 = g .* (L * m1) ./ (illum1 .+ 1e-8 * maximum(abs, illum1));
img2 = g .* (L * m2) ./ (illum2 .+ 1e-8 * maximum(abs, illum2));
imgf = g .* (L * mf) ./ (illumf .+ 1e-8 * maximum(abs, illumf));

@show extrema(img1)
@show extrema(img2)
@show extrema(imgf)

# %% [markdown]
# #### Apply water bottom mute

# %%
img1[v1.==1500.0] .= 0;
img2[v1.==1500.0] .= 0;
imgf[v1.==1500.0] .= 0;

# %% [markdown]
# ## 10. Visualize Results

# %%
mrms1 = 2.5 * sqrt(norm(img1)^2 / length(img1))
mrms2 = 2.5 * sqrt(norm(img2)^2 / length(img2))
mrmsf = 2.5 * sqrt(norm(imgf)^2 / length(imgf))
@show mrms1
@show mrms2
@show mrmsf

figure(figsize=(8,9)); clf()

subplot(3,1,1);imshow(img2,aspect="auto",cmap="gray");
colorbar(orientation="vertical");clim(-mrms2,+mrms2);
title("Migration in Initial Velocity");

subplot(3,1,2);imshow(imgf,aspect="auto",cmap="gray");
colorbar(orientation="vertical");clim(-mrmsf,+mrmsf);
title("Migration in FWI Velocity");

subplot(3,1,3);imshow(img1,aspect="auto",cmap="gray");
colorbar(orientation="vertical");clim(-mrms1,+mrms1);
title("Migration in True Velocity")

tight_layout()

# %% [markdown]
# ## Remove local files and workers

# %%
close(F);
rmprocs(workers());

# %% [markdown]
# ## Record time at end of notebook
# Report total elapsed time to run the notebook

# %%
time_end = time()
@sprintf("Time to run notebook; %.2f minutes\n", (time_end - time_beg) / 60)
