# %% [markdown]
# # Add packages
# This notebook will add all the packages used in these demos to your environment.
#
# This includes `SegyIO` from the SLIM group at Georgia Tech [https://slim.gatech.edu](https://slim.gatech.edu).

# %%
]add https://github.com/slimgroup/SegyIO.jl.git
# Out:
#     Cloning git-repo `https://github.com/slimgroup/SegyIO.jl.git`
#     Fetching: [======>                                  ]
#     g: [========================================>]  100.0 %Fetching: [========>                                ]  18.2 %                           ]  32.4 %                  ]  53.5 % [============================>            ]  67.8 %Fetching: [=============================>           ]  70.7 %Fetching: [=================================>       ]  80.0 %
#    Updating git-repo `https://github.com/slimgroup/SegyIO.jl.git`
#     Fetching: [========================================>]  100.0 %
#    Updating registry at `~/.julia/registries/General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %Fetching: [=====>                                   ]  11.0 %0 %Fetching: [=======>                                 ]  16.8 %===============>                         ]  37.0 %Fetching: [======================>                  ]  53.4 %Fetching: [========================>                ]  58.3 %=============================>           ]  71.6 %Fetching: [======================================>  ]  94.8 %Fetching: [=======================================> ]  97.1 %Fetching: [=======================================> ]  97.2 %
#   Resolving package versions...
#   Installed TimerOutputs ───────────────── v0.5.7
#   Installed ColorTypes ─────────────────── v0.10.9
#   Installed ChainRulesTestUtils ────────── v0.5.3
#   Installed ChainRules ─────────────────── v0.7.32
#   Installed DataAPI ────────────────────── v1.4.0
#   Installed OrderedCollections ─────────── v1.3.2
#   Installed Conda ──────────────────────── v1.5.0
#   Installed Tables ─────────────────────── v1.1.0
#   Installed Zstd_jll ───────────────────── v1.4.5+2
#   Installed ZipFile ────────────────────── v0.9.3
#   Installed LoopVectorization ──────────── v0.8.26
#   Installed ReverseDiff ────────────────── v1.4.3
#   Installed CompilerSupportLibraries_jll ─ v0.3.4+0
#   Installed LAME_jll ───────────────────── v3.100.0+3
#   Installed OpenSpecFun_jll ────────────── v0.5.3+4
#   Installed Tracker ────────────────────── v0.2.12
#   Installed ProgressMeter ──────────────── v1.4.0
#   Installed libfdk_aac_jll ─────────────── v0.1.6+4
#   Installed GPUArrays ──────────────────── v5.2.1
#   Installed SIMDPirates ────────────────── v0.8.25
#   Installed Ogg_jll ────────────────────── v1.3.4+2
#   Installed NLSolversBase ──────────────── v7.5.0
#   Installed PyCall ─────────────────────── v1.92.1
#   Installed DiffEqSensitivity ──────────── v6.33.0
#   Installed Zygote ─────────────────────── v0.5.9
#   Installed FFMPEG_jll ─────────────────── v4.3.1+4
#   Installed StableRNGs ─────────────────── v1.0.0
#   Installed LibVPX_jll ─────────────────── v1.9.0+1
#   Installed Contour ────────────────────── v0.5.5
#   Installed RecipesBase ────────────────── v1.1.0
#   Installed Grisu ──────────────────────── v1.0.0
#   Installed GeneralizedGenerated ───────── v0.2.8
#   Installed GalacticOptim ──────────────── v0.1.3
#   Installed FriBidi_jll ────────────────── v1.0.5+6
#   Installed MbedTLS ────────────────────── v1.0.3
#   Installed RecipesPipeline ────────────── v0.1.13
#   Installed Parsers ────────────────────── v1.0.11
#   Installed Richardson ─────────────────── v1.2.0
#   Installed FiniteDiff ─────────────────── v2.7.1
#   Installed FiniteDifferences ──────────── v0.11.2
#   Installed PlotUtils ──────────────────── v1.0.7
#   Installed ZeroMQ_jll ─────────────────── v4.3.2+5
#   Installed PDMats ─────────────────────── v0.10.1
#   Installed x264_jll ───────────────────── v2020.7.14+2
#   Installed RecursiveArrayTools ────────── v2.7.2
#   Installed Juno ───────────────────────── v0.8.4
#   Installed Unitful ────────────────────── v1.5.0
#   Installed NNlib ──────────────────────── v0.7.6
#   Installed ChainRulesCore ─────────────── v0.9.17
#   Installed OffsetArrays ───────────────── v1.4.0
#   Installed Distances ──────────────────── v0.9.2
#   Installed DiffEqDiffTools ────────────── v1.7.0
#   Installed DocStringExtensions ────────── v0.8.3
#   Installed StaticArrays ───────────────── v0.12.5
#   Installed Bzip2_jll ──────────────────── v1.0.6+5
#   Installed Missings ───────────────────── v0.4.4
#   Installed Showoff ────────────────────── v0.3.2
#   Installed HDF5 ───────────────────────── v0.13.6
#   Installed DiffEqNoiseProcess ─────────── v5.4.0
#   Installed StatsBase ──────────────────── v0.33.2
#   Installed libvorbis_jll ──────────────── v1.3.6+6
#   Installed OpenSSL_jll ────────────────── v1.1.1+6
#   Installed Calculus ───────────────────── v0.5.1
#   Installed LaTeXStrings ───────────────── v1.2.0
#   Installed MbedTLS_jll ────────────────── v2.16.8+1
#   Installed LatticeRules ───────────────── v0.0.1
#   Installed RandomExtensions ───────────── v0.4.2
#   Installed GPUCompiler ────────────────── v0.6.1
#   Installed FFTW_jll ───────────────────── v3.3.9+6
#   Installed Compat ─────────────────────── v3.23.0
#   Installed DistributionsAD ────────────── v0.6.9
#   Installed Requires ───────────────────── v1.1.0
#   Installed x265_jll ───────────────────── v3.0.0+3
#   Installed NameResolution ─────────────── v0.1.5
#   Installed HTTP ───────────────────────── v0.8.19
#   Installed Artifacts ──────────────────── v1.3.0
#   Installed FFTW ───────────────────────── v1.2.4
#   Installed libass_jll ─────────────────── v0.14.0+4
#   Installed MacroTools ─────────────────── v0.5.6
#   Installed VectorizationBase ──────────── v0.12.33
#   Installed CanonicalTraits ────────────── v0.2.3
#   Installed AbstractAlgebra ────────────── v0.11.1
#   Installed CUDA ───────────────────────── v1.3.3
#   Installed Zlib_jll ───────────────────── v1.2.11+18
#   Installed FreeType2_jll ──────────────── v2.10.1+5
#   Installed HDF5_jll ───────────────────── v1.10.5+7
#   Installed Colors ─────────────────────── v0.12.4
#   Installed ArrayInterface ─────────────── v2.13.7
#   Installed JLLWrappers ────────────────── v1.1.3
#   Installed JSON ───────────────────────── v0.21.1
#   Installed QuasiMonteCarlo ────────────── v0.2.1
#   Installed ExprTools ──────────────────── v0.1.3
#   Installed LatinHypercubeSampling ─────── v1.7.3
#   Installed QuadGK ─────────────────────── v2.4.1
#   Installed SymbolicUtils ──────────────── v0.5.2
#   Installed Adapt ──────────────────────── v2.3.0
#   Installed IRTools ────────────────────── v0.4.1
#   Installed ColorSchemes ───────────────── v3.10.1
#   Installed Opus_jll ───────────────────── v1.3.1+3
# ######################################################################### 100.0%
# ######################################################################### 100.0%
# ######################################################################### 100.0%
# ######################################################################### 100.0%
# ######################################################################### 100.0%
# ######################################################################### 100.0%
# ######################################################################### 100.0%
# ######################################################################### 100.0%
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [157a0f19] + SegyIO v0.7.3 `https://github.com/slimgroup/SegyIO.jl.git#master`
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [c3fe647b] ↑ AbstractAlgebra v0.10.0 ⇒ v0.11.1
#   [79e6a3ab] ↑ Adapt v2.0.2 ⇒ v2.3.0
#   [4fba245c] ↑ ArrayInterface v2.11.0 ⇒ v2.13.7
#   [56f22d72] + Artifacts v1.3.0
#   [6e34b625] ↑ Bzip2_jll v1.0.6+3 ⇒ v1.0.6+5
#   [052768ef] ↑ CUDA v1.3.0 ⇒ v1.3.3
#   [49dc2e85] + Calculus v0.5.1
#   [a603d957] ↑ CanonicalTraits v0.2.2 ⇒ v0.2.3
#   [082447d4] ↑ ChainRules v0.7.13 ⇒ v0.7.32
#   [d360d2e6] ↑ ChainRulesCore v0.9.5 ⇒ v0.9.17
#   [cdddcdb0] + ChainRulesTestUtils v0.5.3
#   [35d6a980] ↑ ColorSchemes v3.9.0 ⇒ v3.10.1
#   [3da002f7] ↑ ColorTypes v0.10.8 ⇒ v0.10.9
#   [5ae59095] ↑ Colors v0.12.3 ⇒ v0.12.4
#   [34da2185] ↑ Compat v3.14.0 ⇒ v3.23.0
#   [e66e0078] ↑ CompilerSupportLibraries_jll v0.3.3+0 ⇒ v0.3.4+0
#   [8f4d0f93] ↑ Conda v1.4.1 ⇒ v1.5.0
#   [d38c429a] ↑ Contour v0.5.4 ⇒ v0.5.5
#   [9a962f9c] ↑ DataAPI v1.3.0 ⇒ v1.4.0
#   [01453d9d] + DiffEqDiffTools v1.7.0
#   [77a26b50] ↑ DiffEqNoiseProcess v5.2.0 ⇒ v5.4.0
#   [41bf760c] ↑ DiffEqSensitivity v6.31.1 ⇒ v6.33.0
#   [b4f34e82] ↑ Distances v0.9.0 ⇒ v0.9.2
#   [ced4e74d] ↑ DistributionsAD v0.6.3 ⇒ v0.6.9
#   [ffbed154] ↑ DocStringExtensions v0.8.2 ⇒ v0.8.3
#   [e2ba6199] ↑ ExprTools v0.1.1 ⇒ v0.1.3
#   [b22a6f82] ↑ FFMPEG_jll v4.3.1+1 ⇒ v4.3.1+4
#   [7a1cc6ca] ↑ FFTW v1.2.2 ⇒ v1.2.4
#   [f5851436] ↑ FFTW_jll v3.3.9+5 ⇒ v3.3.9+6
#   [6a86dc24] ↑ FiniteDiff v2.5.2 ⇒ v2.7.1
#   [26cc04aa] + FiniteDifferences v0.11.2
#   [d7e528f0] ↑ FreeType2_jll v2.10.1+3 ⇒ v2.10.1+5
#   [559328eb] ↑ FriBidi_jll v1.0.5+4 ⇒ v1.0.5+6
#   [0c68f7d7] ↑ GPUArrays v5.1.0 ⇒ v5.2.1
#   [61eb1bfa] ↑ GPUCompiler v0.6.0 ⇒ v0.6.1
#   [a75be94c] ↑ GalacticOptim v0.1.1 ⇒ v0.1.3
#   [6b9d7cbe] ↑ GeneralizedGenerated v0.2.7 ⇒ v0.2.8
#   [42e2da0e] + Grisu v1.0.0
#   [f67ccb44] ↑ HDF5 v0.13.5 ⇒ v0.13.6
#   [0234f1f7] ↑ HDF5_jll v1.10.5+5 ⇒ v1.10.5+7
#   [cd3eb016] ↑ HTTP v0.8.17 ⇒ v0.8.19
#   [7869d1d1] ↑ IRTools v0.4.0 ⇒ v0.4.1
#   [692b3bcd] + JLLWrappers v1.1.3
#   [682c06a0] ↑ JSON v0.21.0 ⇒ v0.21.1
#   [e5e0dc1b] ↑ Juno v0.8.3 ⇒ v0.8.4
#   [c1c5ebd0] ↑ LAME_jll v3.100.0+2 ⇒ v3.100.0+3
#   [b964fa9f] ↑ LaTeXStrings v1.1.0 ⇒ v1.2.0
#   [a5e1c1ea] ↑ LatinHypercubeSampling v1.6.4 ⇒ v1.7.3
#   [73f95e8e] + LatticeRules v0.0.1
#   [dd192d2f] ↑ LibVPX_jll v1.9.0+0 ⇒ v1.9.0+1
#   [bdcacae8] ↑ LoopVectorization v0.8.24 ⇒ v0.8.26
#   [1914dd2f] ↑ MacroTools v0.5.5 ⇒ v0.5.6
#   [739be429] ↑ MbedTLS v1.0.2 ⇒ v1.0.3
#   [c8ffd9c3] ↑ MbedTLS_jll v2.16.6+1 ⇒ v2.16.8+1
#   [e1d29d7a] ↑ Missings v0.4.3 ⇒ v0.4.4
#   [d41bc354] ↓ NLSolversBase v7.7.0 ⇒ v7.5.0
#   [872c559c] ↑ NNlib v0.7.4 ⇒ v0.7.6
#   [71a1bf82] ↑ NameResolution v0.1.4 ⇒ v0.1.5
#   [6fe1bfb0] ↑ OffsetArrays v1.1.2 ⇒ v1.4.0
#   [e7412a2a] ↑ Ogg_jll v1.3.4+1 ⇒ v1.3.4+2
#   [458c3c95] ↑ OpenSSL_jll v1.1.1+5 ⇒ v1.1.1+6
#   [efe28fd5] ↑ OpenSpecFun_jll v0.5.3+3 ⇒ v0.5.3+4
#   [91d4177d] ↑ Opus_jll v1.3.1+2 ⇒ v1.3.1+3
#   [bac558e1] ↑ OrderedCollections v1.3.0 ⇒ v1.3.2
#   [90014a1f] ↑ PDMats v0.10.0 ⇒ v0.10.1
#   [69de0a69] ↑ Parsers v1.0.10 ⇒ v1.0.11
#   [995b91a9] ↑ PlotUtils v1.0.5 ⇒ v1.0.7
#   [92933f4c] ↑ ProgressMeter v1.3.2 ⇒ v1.4.0
#   [438e738f] ↑ PyCall v1.91.4 ⇒ v1.92.1
#   [1fd47b50] ↑ QuadGK v2.4.0 ⇒ v2.4.1
#   [8a4e6c94] ↑ QuasiMonteCarlo v0.2.0 ⇒ v0.2.1
#   [fb686558] + RandomExtensions v0.4.2
#   [3cdcf5f2] ↑ RecipesBase v1.0.2 ⇒ v1.1.0
#   [01d81517] ↑ RecipesPipeline v0.1.12 ⇒ v0.1.13
#   [731186ca] ↑ RecursiveArrayTools v2.6.0 ⇒ v2.7.2
#   [ae029012] ↑ Requires v1.0.1 ⇒ v1.1.0
#   [37e2e3b7] ↑ ReverseDiff v1.4.2 ⇒ v1.4.3
#   [708f8203] + Richardson v1.2.0
#   [21efa798] ↑ SIMDPirates v0.8.24 ⇒ v0.8.25
#   [157a0f19] + SegyIO v0.7.3 `https://github.com/slimgroup/SegyIO.jl.git#master`
#   [992d4aef] ↑ Showoff v0.3.1 ⇒ v0.3.2
#   [860ef19b] + StableRNGs v1.0.0
#   [90137ffa] ↑ StaticArrays v0.12.4 ⇒ v0.12.5
#   [2913bbd2] ↑ StatsBase v0.33.0 ⇒ v0.33.2
#   [d1185830] ↑ SymbolicUtils v0.5.0 ⇒ v0.5.2
#   [bd369af6] ↑ Tables v1.0.5 ⇒ v1.1.0
#   [a759f4b9] ↑ TimerOutputs v0.5.6 ⇒ v0.5.7
#   [9f7883ad] ↑ Tracker v0.2.11 ⇒ v0.2.12
#   [1986cc42] ↑ Unitful v1.4.0 ⇒ v1.5.0
#   [3d5dd08c] ↑ VectorizationBase v0.12.32 ⇒ v0.12.33
#   [8f1865be] ↑ ZeroMQ_jll v4.3.2+4 ⇒ v4.3.2+5
#   [a5390f91] ↑ ZipFile v0.9.2 ⇒ v0.9.3
#   [83775a58] ↑ Zlib_jll v1.2.11+15 ⇒ v1.2.11+18
#   [3161d3a3] ↑ Zstd_jll v1.4.5+0 ⇒ v1.4.5+2
#   [e88e6eb3] ↑ Zygote v0.5.4 ⇒ v0.5.9
#   [0ac62f75] ↑ libass_jll v0.14.0+3 ⇒ v0.14.0+4
#   [f638f0a6] ↑ libfdk_aac_jll v0.1.6+3 ⇒ v0.1.6+4
#   [f27f6e37] ↑ libvorbis_jll v1.3.6+5 ⇒ v1.3.6+6
#   [1270edf5] ↑ x264_jll v2020.7.14+1 ⇒ v2020.7.14+2
#   [dfaa095f] ↑ x265_jll v3.0.0+2 ⇒ v3.0.0+3
#    Building Conda ─→ `~/.julia/packages/Conda/x5ml4/deps/build.log`
#    Building PyCall → `~/.julia/packages/PyCall/BcTLp/deps/build.log`

# %%
using Pkg
Pkg.add.(["DelimitedFiles", "Distributed", "DistributedArrays", "DistributedJets", 
    "DistributedOperations", "JetPack", "JetPackDSP", "JetPackTransforms", 
    "JetPackWaveFD", "Jets", "LineSearches", "LinearAlgebra", "Optim", "ParallelOperations", 
    "Printf", "PyPlot", "Random", "Schedulers", "TeaSeis", "WaveFD"])
nothing

# %% [markdown]
# # Precompile packages

# %%
using DelimitedFiles, Distributed, DistributedArrays, DistributedJets, DistributedOperations
using JetPack, JetPackDSP, JetPackTransforms, JetPackWaveFD, Jets 
using LineSearches, LinearAlgebra, Optim, ParallelOperations, Printf 
using PyPlot, Random, Schedulers, TeaSeis, WaveFD, SegyIO
nothing
