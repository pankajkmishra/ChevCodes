# %% [markdown]
# # Add packages
# This notebook will add all the packages used in these demos to your environment.
#
# This includes `SegyIO` from the SLIM group at Georgia Tech [https://slim.gatech.edu](https://slim.gatech.edu).

# %%
]add https://github.com/slimgroup/SegyIO.jl.git
# Out:
#     Cloning git-repo `https://github.com/slimgroup/SegyIO.jl.git`
#     Fetching: [======>                                  ]
#     g: [========================================>]  100.0 %Fetching: [========>                                ]  18.2 %                           ]  32.4 %Fetching: [================>                        ]  39.2 %                  ]  53.4 % [============================>            ]  67.7 %===============================>         ]  76.6 %Fetching: [=================================>       ]  80.0 %
#    Updating git-repo `https://github.com/slimgroup/SegyIO.jl.git`
#     Fetching: [========================================>]  100.0 %
#    Updating registry at `~/.julia/registries/General`
#   Resolving package versions...
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [157a0f19] + SegyIO v0.7.3 `https://github.com/slimgroup/SegyIO.jl.git#master`
# Updating `~/.julia/environments/v1.5/Manifest.toml`
# ...

# %%
using Pkg
Pkg.add.(["DelimitedFiles", "Distributed", "DistributedArrays", "DistributedJets", 
    "DistributedOperations", "JetPack", "JetPackDSP", "JetPackTransforms", 
    "JetPackWaveFD", "Jets", "LineSearches", "LinearAlgebra", "Optim", "ParallelOperations", 
    "Printf", "PyPlot", "Random", "Schedulers", "TeaSeis", "WaveFD", "MAT"])
nothing
# Out:
#   Resolving package versions...
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [8bb1440f] + DelimitedFiles
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [8bb1440f] + DelimitedFiles
#   Resolving package versions...
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [8ba89e20] + Distributed
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`
#   Resolving package versions...
#   Installed Primes ──────────── v0.4.0
#   Installed DistributedArrays ─ v0.6.5
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [aaf54ef3] + DistributedArrays v0.6.5
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [aaf54ef3] + DistributedArrays v0.6.5
#   [27ebfcd6] + Primes v0.4.0
#   [37e2e46d] + LinearAlgebra
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   Resolving package versions...
#   Installed DistributedOperations ─ v1.0.0
#   Installed DistributedJets ─────── v1.0.0
#   Installed Jets ────────────────── v1.0.0
# ...

# %% [markdown]
# # Precompile packages

# %%
using DelimitedFiles, Distributed, DistributedArrays, DistributedJets, DistributedOperations
using JetPack, JetPackDSP, JetPackTransforms, JetPackWaveFD, Jets 
using LineSearches, LinearAlgebra, Optim, ParallelOperations, Printf 
using PyPlot, Random, Schedulers, TeaSeis, WaveFD, SegyIO, MAT
nothing
# Out:
# ┌ Info: Precompiling DistributedArrays [aaf54ef3-cdf8-58ed-94cc-d582ad619b94]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling DistributedJets [5b65064a-1d0b-5b23-8760-570290dfee43]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling JetPack [24ef3835-3876-54c3-8a7a-956cf69ca0b2]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling JetPackDSP [b1babd66-454c-5c15-86a3-b3c308963df9]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling JetPackTransforms [e0630bc5-6e1f-509c-a3e4-0aea24bd2b1c]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling JetPackWaveFD [30ac78e6-0b88-494d-b61b-9674962a0c3e]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling LineSearches [d3d80556-e9d4-5f37-9878-2ab0fcc64255]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling Optim [429524aa-4258-5aef-a3af-852621145aeb]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling ParallelOperations [09c1cff2-b94d-4c31-85a1-721512e21c63]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# ...

# %%
file = matopen("SEAM_vp.mat")
# Out:
# File "SEAM_vp.mat" does not exist and create was not specified
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] matopen(::String, ::Bool, ::Bool, ::Bool, ::Bool, ::Bool, ::Bool) at /Users/pkmishra/.julia/packages/MAT/5SDtD/src/MAT.jl:44
#  [3] matopen(::String, ::String; compress::Bool) at /Users/pkmishra/.julia/packages/MAT/5SDtD/src/MAT.jl:88
#  [4] matopen at /Users/pkmishra/.julia/packages/MAT/5SDtD/src/MAT.jl:88 [inlined]
#  [5] #matopen#2 at /Users/pkmishra/.julia/packages/MAT/5SDtD/src/MAT.jl:97 [inlined]
#  [6] matopen(::String) at /Users/pkmishra/.julia/packages/MAT/5SDtD/src/MAT.jl:97
#  [7] top-level scope at In[7]:1
#  [8] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
